# %%
import findspark
findspark.init("/opt/manual/spark")

from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import *

# %%
spark = (
    SparkSession.builder
    .appName("Spark Bucketing")
    .master("yarn")
    .enableHiveSupport()
    .getOrCreate())

# %% [markdown]
# # read market1mil

# %%
market1mil = spark.read.format("csv") \
.option("header", True) \
.option("inferSchema", True) \
.option("sep", ",") \
.load("/user/train/datasets/market1mil.csv.gz") \
.orderBy(F.rand())

# %%
market1mil = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .option("sep", ";") \
    .option("compression", "gzip") \
    .load("/user/train/datasets/market1mil.csv.gz") \
    .orderBy(F.rand()).withColumn("LOGICALREF", F.col("LOGICALREF").cast(IntegerType()))

# %%
market1mil.limit(3).toPandas()
# Out:
#    LOGICALREF  COUNT_  ITEMCODE                     ITEMNAME  FICHENO  \
# 0      835552       1      5736                        CILEK   211098
# 1      544158       1      1935  DR.OETKER JOLE 100 GR CILEK   142233
# 2      952905       1      5692                       KARPUZ   238847
#
#               DATE_ AMOUNT PRICE LINENETTOTAL LINENET  ...  \
# 0   1.05.2017 00:00   0,65   4,5         2,93    2,71  ...
# 1  23.03.2017 00:00      1   2,1          2,1    1,94  ...
# 2  17.05.2017 00:00  5,945  1,25         7,43    6,88  ...
#
#             CLIENTNAME BRANDCODE      BRAND CATEGORY_NAME1 CATEGORY_NAME2  \
# 0        Rojin RENÇBER       A25        HAL    MEYVE SEBZE          MEYVE
# 1  Şilan TARIKOĞULLARI        40  DR.OETKER           GIDA      TOZ TATLI
# 2       Alperen ELİBOZ       A25        HAL    MEYVE SEBZE          MEYVE
#
#   CATEGORY_NAME3         STARTDATE           ENDDATE SPECODE  \
# 0           None   2.05.2017 19:24   2.05.2017 19:24       K
# 1           None  24.03.2017 09:57  24.03.2017 09:58       K
# 2           None  18.05.2017 12:39  18.05.2017 12:39       E
#
#   CAPIBLOCK_CREADEDDATE
# 0      14.07.2018 01:48
# 1      14.07.2018 01:56
# 2      14.07.2018 02:14
#
# [3 rows x 28 columns]

# %%
market1mil.printSchema()
# Out:
# root
#  |-- LOGICALREF: integer (nullable = true)
#  |-- COUNT_: integer (nullable = true)
#  |-- ITEMCODE: integer (nullable = true)
#  |-- ITEMNAME: string (nullable = true)
#  |-- FICHENO: integer (nullable = true)
#  |-- DATE_: string (nullable = true)
#  |-- AMOUNT: string (nullable = true)
#  |-- PRICE: string (nullable = true)
#  |-- LINENETTOTAL: string (nullable = true)
#  |-- LINENET: string (nullable = true)
#  |-- BRANCHNR: integer (nullable = true)
#  |-- BRANCH: string (nullable = true)
#  |-- SALESMAN: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- REGION: string (nullable = true)
#  |-- LATITUDE: string (nullable = true)
#  |-- LONGITUDE: string (nullable = true)
#  |-- CLIENTCODE: string (nullable = true)
#  |-- CLIENTNAME: string (nullable = true)
#  |-- BRANDCODE: string (nullable = true)
#  |-- BRAND: string (nullable = true)
#  |-- CATEGORY_NAME1: string (nullable = true)
#  |-- CATEGORY_NAME2: string (nullable = true)
#  |-- CATEGORY_NAME3: string (nullable = true)
#  |-- STARTDATE: string (nullable = true)
#  |-- ENDDATE: string (nullable = true)
#  |-- SPECODE: string (nullable = true)
#  |-- CAPIBLOCK_CREADEDDATE: string (nullable = true)

# %%
market5mil = spark.read.format("parquet") \
.load("/user/train/datasets/market5mil_parquet") \
.orderBy(F.rand())

# %%
market5mil.limit(2).toPandas()
# Out:
#    LOGICALREF  COUNT_     ITEMCODE                                ITEMNAME  \
# 0     1900752       1  00000006981  ETI CIN TEK LOKMALIK PORTAKALLI 112 GR
# 1     4670731       1  00000021300             H.SAKIR SAB.BEYAZ 4LU DOGAL
#
#             FICHENO      DATE_  AMOUNT  PRICE  LINENETTOTAL  LINENET  ...  \
# 0  0000000000457893 2017-08-22       1   1.00          1.00     0.93  ...
# 1  0000000000627649 2018-12-17       1   3.45          3.45     2.93  ...
#
#       CLIENTNAME BRANDCODE    BRAND CATEGORY_NAME1 CATEGORY_NAME2  \
# 0   Zeliha ERÇİŞ        44      ETİ           GIDA  BÜSKİVİ ÇEREZ
# 1  Toprak KURSUN        58  H.ŞAKİR       KOZMETİK      DUŞ BANYO
#
#    CATEGORY_NAME3           STARTDATE             ENDDATE SPECODE  \
# 0         BÜSKİVİ 2017-08-23 14:33:00 2017-08-23 14:34:19       K
# 1   KATI SABUNLAR 2018-12-18 14:36:52 2018-12-18 14:37:14       E
#
#   CAPIBLOCK_CREADEDDATE
# 0   2018-07-14 01:58:56
# 1   2018-07-14 02:01:48
#
# [2 rows x 28 columns]

# %%
market5mil.printSchema()
# Out:
# root
#  |-- LOGICALREF: integer (nullable = true)
#  |-- COUNT_: integer (nullable = true)
#  |-- ITEMCODE: string (nullable = true)
#  |-- ITEMNAME: string (nullable = true)
#  |-- FICHENO: string (nullable = true)
#  |-- DATE_: timestamp (nullable = true)
#  |-- AMOUNT: integer (nullable = true)
#  |-- PRICE: float (nullable = true)
#  |-- LINENETTOTAL: float (nullable = true)
#  |-- LINENET: float (nullable = true)
#  |-- BRANCHNR: string (nullable = true)
#  |-- BRANCH: string (nullable = true)
#  |-- SALESMAN: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- REGION: string (nullable = true)
#  |-- LATITUDE: float (nullable = true)
#  |-- LONGITUDE: float (nullable = true)
#  |-- CLIENTCODE: string (nullable = true)
#  |-- CLIENTNAME: string (nullable = true)
#  |-- BRANDCODE: string (nullable = true)
#  |-- BRAND: string (nullable = true)
#  |-- CATEGORY_NAME1: string (nullable = true)
#  |-- CATEGORY_NAME2: string (nullable = true)
#  |-- CATEGORY_NAME3: string (nullable = true)
#  |-- STARTDATE: timestamp (nullable = true)
#  |-- ENDDATE: timestamp (nullable = true)
#  |-- SPECODE: string (nullable = true)
#  |-- CAPIBLOCK_CREADEDDATE: timestamp (nullable = true)

# %%
spark.conf.get("spark.sql.sources.bucketing.enabled")
# Out:
# 'true'

# %% [markdown]
# # Join

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", -1)

# %%
joined_df = market1mil.join(market5mil, "LOGICALREF") \
.drop(*market1mil.columns)

# %%
import time 
start_time = time.time()

joined_df.limit(5).toPandas()

print("--- %s seconds ---" %(time.time()- start_time))
# Out:
# --- 17.546129941940308 seconds ---

# %%
joined_df.explain()
# Out:
# == Physical Plan ==
# *(5) Project
# +- *(5) SortMergeJoin [LOGICALREF#371], [LOGICALREF#141], Inner
#    :- *(2) Sort [LOGICALREF#371 ASC NULLS FIRST], false, 0
#    :  +- Exchange hashpartitioning(LOGICALREF#371, 200), true, [id=#296]
#    :     +- *(1) Project [cast(LOGICALREF#314 as int) AS LOGICALREF#371]
#    :        +- *(1) Filter isnotnull(cast(LOGICALREF#314 as int))
#    :           +- FileScan csv [LOGICALREF#314] Batched: false, DataFilters: [isnotnull(cast(LOGICALREF#314 as int))], Format: CSV, Location: InMemoryFileIndex[hdfs://localhost:9000/user/train/datasets/market1mil.csv.gz], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<LOGICALREF:string>
#    +- *(4) Sort [LOGICALREF#141 ASC NULLS FIRST], false, 0
#       +- Exchange hashpartitioning(LOGICALREF#141, 200), true, [id=#306]
#          +- *(3) Project [LOGICALREF#141]
#             +- *(3) Filter isnotnull(LOGICALREF#141)
#                +- *(3) ColumnarToRow
#                   +- FileScan parquet [LOGICALREF#141] Batched: true, DataFilters: [isnotnull(LOGICALREF#141)], Format: Parquet, Location: InMemoryFileIndex[hdfs://localhost:9000/user/train/datasets/market5mil_parquet], PartitionFilters: [], PushedFilters: [IsNotNull(LOGICALREF)], ReadSchema: struct<LOGICALREF:int>

# %% [markdown]
# # write hive with buckets

# %%
import time 
start_time = time.time()

market1mil.orderBy(F.asc("LOGICALREF")) \
.write.format("parquet") \
.mode("overwrite") \
.bucketBy(8, "LOGICALREF") \
.saveAsTable("market1mil_tbl")

print("--- %s seconds ---" %(time.time()- start_time))
# Out:
# --- 286.9814684391022 seconds ---

# %%
import time 
start_time = time.time()

market5mil.orderBy(F.asc("LOGICALREF")) \
.write.format("parquet") \
.mode("overwrite") \
.bucketBy(8, "LOGICALREF") \
.saveAsTable("market5mil_tbl")

print("--- %s seconds ---" %(time.time()- start_time))
# Out:
# --- 415.4062271118164 seconds ---

# %%
spark.sql("show tables").show()
# Out:
# +--------+---------------+-----------+
# |database|      tableName|isTemporary|
# +--------+---------------+-----------+
# | default|    advertising|      false|
# | default| market1mil_tbl|      false|
# | default| market5mil_tbl|      false|
# | default|order_items_tbl|      false|
# | default|     orders_tbl|      false|
# +--------+---------------+-----------+

# %%
market1mil_tbl = spark.sql("select * from market1mil_tbl")

# %%
market1mil_tbl.limit(5).toPandas()
# Out:
#    LOGICALREF  COUNT_  ITEMCODE                            ITEMNAME  FICHENO  \
# 0          12       1     13519     FILIZ MAKARNA KISA KESME 500 GR    15561
# 1          13       1      8639  BINGO ULTRA CAM.SUYU 750 ML KLASIK    15561
# 2          14       1      6372                   DERYA KASAR 250GR    15561
# 3          18       1      5461                            KIVIRCIK    15563
# 4          38       1      5362       SİHİRLİ ELLER CİG KÖFTE 200GR    15572
#
#              DATE_ AMOUNT PRICE LINENETTOTAL LINENET  ...       CLIENTNAME  \
# 0  2.01.2017 00:00      1   1,1          1,1    1,02  ...  Nurgül ZÜLFİKAR
# 1  2.01.2017 00:00      1  2,45         2,45    2,08  ...  Nurgül ZÜLFİKAR
# 2  2.01.2017 00:00      1   4,9          4,9    4,54  ...  Nurgül ZÜLFİKAR
# 3  2.01.2017 00:00      1  1,25         1,25    1,16  ...  Ege YOSUNLUKAYA
# 4  2.01.2017 00:00      2   4,4          8,8    8,15  ...      Hasan ÖZYOL
#
#   BRANDCODE          BRAND     CATEGORY_NAME1  CATEGORY_NAME2  CATEGORY_NAME3  \
# 0        52          FİLİZ               GIDA         MAKARNA        MAKARNA
# 1       224          BİNGO  DETERJAN TEMİZLİK  ÇAMAŞIR YIKAMA  ÇAMAŞIR SULARI
# 2       153          DERYA    SÜT KAHVALTILIK          PEYNİR   KAŞAR PEYNİRİ
# 3       A25            HAL        MEYVE SEBZE           SEBZE            None
# 4       346  SİHİRLİ ELLER               GIDA  HAZIR YEMEKLER            MEZE
#
#          STARTDATE          ENDDATE SPECODE CAPIBLOCK_CREADEDDATE
# 0  3.01.2017 09:25  3.01.2017 09:25       K      14.07.2018 02:24
# 1  3.01.2017 09:25  3.01.2017 09:25       K      14.07.2018 02:24
# 2  3.01.2017 09:25  3.01.2017 09:25       K      14.07.2018 02:24
# 3  3.01.2017 09:35  3.01.2017 09:36       E      14.07.2018 02:17
# 4  3.01.2017 09:56  3.01.2017 09:56       E      14.07.2018 01:42
#
# [5 rows x 28 columns]

# %%
market5mil_tbl = spark.sql("select * from market5mil_tbl")

# %%
market5mil_tbl.limit(5).toPandas()
# Out:
#    LOGICALREF  COUNT_     ITEMCODE                            ITEMNAME  \
# 0          12       1  00000013519     FILIZ MAKARNA KISA KESME 500 GR
# 1          13       1  00000008639  BINGO ULTRA CAM.SUYU 750 ML KLASIK
# 2          14       1  00000006372                   DERYA KASAR 250GR
# 3          18       1  00000005461                            KIVIRCIK
# 4          38       1  00000005362       SİHİRLİ ELLER CİG KÖFTE 200GR
#
#             FICHENO      DATE_  AMOUNT  PRICE  LINENETTOTAL  LINENET  ...  \
# 0  0000000000015561 2017-01-02       1   1.10          1.10     1.02  ...
# 1  0000000000015561 2017-01-02       1   2.45          2.45     2.08  ...
# 2  0000000000015561 2017-01-02       1   4.90          4.90     4.54  ...
# 3  0000000000015563 2017-01-02       1   1.25          1.25     1.16  ...
# 4  0000000000015572 2017-01-02       2   4.40          8.80     8.15  ...
#
#         CLIENTNAME BRANDCODE          BRAND     CATEGORY_NAME1  \
# 0  Nurgül ZÜLFİKAR        52          FİLİZ               GIDA
# 1  Nurgül ZÜLFİKAR       224          BİNGO  DETERJAN TEMİZLİK
# 2  Nurgül ZÜLFİKAR       153          DERYA    SÜT KAHVALTILIK
# 3  Ege YOSUNLUKAYA       A25            HAL        MEYVE SEBZE
# 4      Hasan ÖZYOL       346  SİHİRLİ ELLER               GIDA
#
#    CATEGORY_NAME2  CATEGORY_NAME3           STARTDATE             ENDDATE  \
# 0         MAKARNA        MAKARNA  2017-01-03 09:25:03 2017-01-03 09:25:43
# 1  ÇAMAŞIR YIKAMA  ÇAMAŞIR SULARI 2017-01-03 09:25:03 2017-01-03 09:25:43
# 2          PEYNİR   KAŞAR PEYNİRİ 2017-01-03 09:25:03 2017-01-03 09:25:43
# 3           SEBZE            None 2017-01-03 09:35:35 2017-01-03 09:36:10
# 4  HAZIR YEMEKLER            MEZE 2017-01-03 09:56:48 2017-01-03 09:56:56
#
#   SPECODE CAPIBLOCK_CREADEDDATE
# 0       K   2018-07-14 02:24:47
# 1       K   2018-07-14 02:24:47
# 2       K   2018-07-14 02:24:47
# 3       E   2018-07-14 02:17:23
# 4       E   2018-07-14 01:42:33
#
# [5 rows x 28 columns]

# %%
joined_df2 = market1mil_tbl.join(market5mil_tbl,"LOGICALREF") \
.drop(*market1mil_tbl.columns)

# %%
import time 
start_time = time.time()

joined_df2.limit(5).toPandas()

print("--- %s seconds ---" %(time.time()- start_time))
# Out:
# --- 9.446430683135986 seconds ---

# %%
spark.stop()
